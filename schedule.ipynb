# %%
# !pip install pandas
# !pip install openpyxl

# %%
import pandas

# %%
dataframe = pandas.read_excel("data/View_My_Courses.xlsx",skiprows=2)
# Out:
# C:\Users\Andrei\AppData\Roaming\Python\Python312\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dataframe
# Out:
#                                            Unnamed: 0  \
# 0   Andrei Doroteo (41101338) - Faculty of Science...
# 1   Andrei Doroteo (41101338) - Faculty of Science...
# 2   Andrei Doroteo (41101338) - Faculty of Science...
# 3   Andrei Doroteo (41101338) - Faculty of Science...
# 4   Andrei Doroteo (41101338) - Faculty of Science...
# 5   Andrei Doroteo (41101338) - Faculty of Science...
# 6   Andrei Doroteo (41101338) - Faculty of Science...
# 7   Andrei Doroteo (41101338) - Faculty of Science...
# 8   Andrei Doroteo (41101338) - Faculty of Science...
# 9   Andrei Doroteo (41101338) - Faculty of Science...
# 10  Andrei Doroteo (41101338) - Faculty of Science...
# 11  Andrei Doroteo (41101338) - Faculty of Science...
# 12  Andrei Doroteo (41101338) - Faculty of Science...
# 13  Andrei Doroteo (41101338) - Faculty of Science...
# 14  Andrei Doroteo (41101338) - Faculty of Science...
#
#                                        Course Listing  Credits Grading Basis  \
# 0   STAT_V 200 - Elementary Statistics for Applica...        3        Graded
# 1   STAT_V 200 - Elementary Statistics for Applica...        3        Graded
# 2   ANTH_V 100 - Introduction to Cultural Anthropo...        3        Graded
# 3   ANTH_V 100 - Introduction to Cultural Anthropo...        3        Graded
# 4                           MATH_V 200 - Calculus III        3        Graded
# 5   STAT_V 201 - Statistical Inference for Data Sc...        3        Graded
# 6                         MATH_V 221 - Matrix Algebra        3        Graded
# 7   EOSC_V 114 - The Catastrophic Earth: Natural D...        3        Graded
# 8          SCIE_V 113 - First-Year Seminar in Science        3        Graded
# 9          SCIE_V 113 - First-Year Seminar in Science        3        Graded
# 10                 CPSC_V 210 - Software Construction        4        Graded
# 11                 CPSC_V 210 - Software Construction        4        Graded
# 12                 CPSC_V 121 - Models of Computation        4        Graded
# 13                 CPSC_V 121 - Models of Computation        4        Graded
# 14                 CPSC_V 121 - Models of Computation        4        Graded
#
#                                               Section Instructional Format  \
# 0   STAT_V 200-103 - Elementary Statistics for App...              Lecture
# 1   STAT_V 200-L1K - Elementary Statistics for App...           Laboratory
# 2   ANTH_V 100-A_D3D - Introduction to Cultural An...           Discussion
# 3   ANTH_V 100-A_003 - Introduction to Cultural An...              Lecture
# 4                       MATH_V 200-101 - Calculus III              Lecture
# 5   STAT_V 201-203 - Statistical Inference for Dat...              Lecture
# 6                     MATH_V 221-201 - Matrix Algebra              Lecture
# 7   EOSC_V 114-202 - The Catastrophic Earth: Natur...              Lecture
# 8      SCIE_V 113-201 - First-Year Seminar in Science              Lecture
# 9      SCIE_V 113-10K - First-Year Seminar in Science              Seminar
# 10             CPSC_V 210-103 - Software Construction              Lecture
# 11             CPSC_V 210-L1C - Software Construction           Laboratory
# 12             CPSC_V 121-L2E - Models of Computation           Laboratory
# 13             CPSC_V 121-T2L - Models of Computation           Discussion
# 14             CPSC_V 121-202 - Models of Computation              Lecture
#
#          Delivery Mode                                   Meeting Patterns  \
# 0   In Person Learning  2024-09-03 - 2024-12-06 | Mon Wed Fri | 2:00 p...
# 1   In Person Learning  2024-09-05 - 2024-12-05 | Thu | 11:00 a.m. - 1...
# 2   In Person Learning  2024-09-06 - 2024-12-06 | Fri | 12:00 p.m. - 1...
# 3   In Person Learning  2024-09-03 - 2024-12-04 | Mon Wed | 12:00 p.m....
# 4   In Person Learning  2024-09-03 - 2024-12-05 | Tue Thu | 8:00 a.m. ...
# 5   In Person Learning  2025-01-06 - 2025-02-12 | Mon Wed | 8:00 a.m. ...
# 6   In Person Learning  2025-01-07 - 2025-02-13 | Tue Thu | 8:00 a.m. ...
# 7   In Person Learning  2025-01-06 - 2025-02-14 | Mon Wed Fri | 1:00 p...
# 8      Online Learning                                                NaN
# 9   In Person Learning  2025-01-06 - 2025-02-14 | Mon Wed Fri | 10:00 ...
# 10  In Person Learning  2024-09-03 - 2024-12-06 | Mon Wed Fri | 4:00 p...
# 11  In Person Learning  2024-09-03 - 2024-12-03 | Tue | 11:00 a.m. - 1...
# 12  In Person Learning  2025-01-07 - 2025-02-11 | Tue | 3:00 p.m. - 5:...
# 13  In Person Learning  2025-01-08 - 2025-02-12 | Wed | 11:00 a.m. - 1...
# 14  In Person Learning  2025-01-07 - 2025-02-13 | Tue Thu | 12:30 p.m....
#
#    Registration Status                                         Instructor  \
# 0           Registered                                Rodolfo Lourenzutti
# 1           Registered                                                NaN
# 2           Registered                                    Charles Menzies
# 3           Registered                                    Charles Menzies
# 4           Registered                                        Albert Chau
# 5           Registered                                Rodolfo Lourenzutti
# 6           Registered                                                NaN
# 7           Registered  David Sasse\n\nDouglas McCollor\n\nLaura Lukes...
# 8           Registered                  Caitlin Donnelly\n\nMarcia Graves
# 9           Registered                                                NaN
# 10          Registered                                       Firas Moosvi
# 11          Registered                                                NaN
# 12          Registered                                                NaN
# 13          Registered                                                NaN
# 14          Registered                                    Karina Mochetti
#
#    Start Date   End Date
# 0  2024-09-03 2024-12-06
# 1  2024-09-03 2024-12-06
# 2  2024-09-03 2024-12-06
# 3  2024-09-03 2024-12-06
# 4  2024-09-03 2024-12-05
# 5  2025-01-06 2025-04-07
# 6  2025-01-07 2025-04-08
# 7  2025-01-06 2025-04-07
# 8  2025-01-06 2025-04-08
# 9  2025-01-06 2025-04-08
# 10 2024-09-03 2024-12-06
# 11 2024-09-03 2024-12-06
# 12 2025-01-06 2025-04-08
# 13 2025-01-06 2025-04-08
# 14 2025-01-06 2025-04-08

# %%
def get_name(section:str, name:str="") -> str:
    """
    consumes a section provided by workday. produces the class name in the format "<class name> <class number> <section>"
    """

    try:
        if section == "":
           return section
        
        elif section[0] == " " and section[1] == "-" and section[2] == " ":
         return name.replace('_V', '').replace('-', ' ')
    
        else:
            return get_name(section=section[1:], name = name + section[0])
    
    except IndexError:
        print("Invalid Section") # !!!
        return ""

# %%
dataframe_names = dataframe["Section"].apply(get_name)

dataframe_names
# Out:
# 0       STAT 200 103
# 1       STAT 200 L1K
# 2     ANTH 100 A_D3D
# 3     ANTH 100 A_003
# 4       MATH 200 101
# 5       STAT 201 203
# 6       MATH 221 201
# 7       EOSC 114 202
# 8       SCIE 113 201
# 9       SCIE 113 10K
# 10      CPSC 210 103
# 11      CPSC 210 L1C
# 12      CPSC 121 L2E
# 13      CPSC 121 T2L
# 14      CPSC 121 202
# Name: Section, dtype: object

# %%
# cols = ["Section","Meeting Patterns","Start Date","End Date"]
# dataframe_filtered = dataframe[cols]
# dataframe_filtered
